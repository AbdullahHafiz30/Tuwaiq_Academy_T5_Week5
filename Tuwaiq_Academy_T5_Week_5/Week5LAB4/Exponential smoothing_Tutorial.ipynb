# %% [markdown]
# #**Exponential smoothing**

# %% [markdown]
# ##  install these libraries using pip:

# %%
# !pip install pandas matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\abo_o\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.2)
# Requirement already satisfied: matplotlib in c:\users\abo_o\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.1)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\abo_o\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abo_o\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abo_o\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\abo_o\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abo_o\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\abo_o\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abo_o\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abo_o\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\abo_o\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\abo_o\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abo_o\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\abo_o\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading dataset

# %%
data = pd.read_csv('D:\\Tuwaiq Academy\\Tuwaiq_Academy_T5_Week_5\\Week5LAB4\\Datasets\\airline-passengers.csv', parse_dates=['Month'], index_col='Month')
print(data.head())
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# ## Visualizing the data
# ### Before we apply simple exponential smoothing to the data, let’s visualize it to get a better understanding of its properties. We can use the plot function of pandas to create a line plot of the data:

# %%
plt.plot(data)
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.show()

# %% [markdown]
# We can see that the number of passengers appears to be increasing over time, with some seasonality as well.

# %% [markdown]
# #**Single Exponential smoothing**
# ### Now that we’ve loaded and visualized the data, we can perform simple exponential smoothing using the SimpleExpSmoothing function from the statsmodels library.
#
# ### Then, we’ll create an instance of the SimpleExpSmoothing class, passing in the data as an argument, and then fit the model to the data using the fit method, This will calculate the smoothing parameters and fit the model to the data.

# %%
from statsmodels.tsa.api import SimpleExpSmoothing
model = SimpleExpSmoothing(data)
model_single_fit = model.fit()
# Out:
# C:\Users\abo_O\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
from statsmodels.tsa.api import SimpleExpSmoothing
model = SimpleExpSmoothing(data)
model_single_fit = model.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# ## Making predictions
# ### Finally, we can use the forecast method of the model to make predictions for future values of the time series, where the argument represents the number of periods to forecast. This will produce a forecast for the next six months:

# %%
forecast_single = model_single_fit.forecast(6)
print(forecast_single)
# Out:
# 1961-01-01    431.791781
# 1961-02-01    431.791781
# 1961-03-01    431.791781
# 1961-04-01    431.791781
# 1961-05-01    431.791781
# 1961-06-01    431.791781
# Freq: MS, dtype: float64

# %%
forecast_single = model_single_fit.forecast(6)
print(forecast_single)
# Out:
# 1961-01-01    431.791781
# 1961-02-01    431.791781
# 1961-03-01    431.791781
# 1961-04-01    431.791781
# 1961-05-01    431.791781
# 1961-06-01    431.791781
# Freq: MS, dtype: float64

# %% [markdown]
# ## Visualize Single Exponential Smoothing
# ### Let’s set the forecast to 40, and check the trend for next 40 months.

# %%
forecast_single = model_single_fit.forecast(40)

# %%
forecast_single = model_single_fit.forecast(40)

# %%
plt.plot(data, label='Original Data')
plt.plot(model_single_fit.fittedvalues, label='Fitted Values')
plt.plot(forecast_single, label='Forecast')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.title('Single Exponential Smoothing')
plt.legend()
plt.show()

# %% [markdown]
# #**Double Exponential Smoothing**
#
# ### Double exponential smoothing, also known as Holt’s method, extends single exponential smoothing to capture trends in the data. It involves forecasting both the level and trend components of the time series.
#
# ### Now, let’s write the code to perform double exponential smoothing (Holt’s method) using the Holt function from the statsmodels library:
#
#
# *   Create an instance of Holt class
#
# *   Fit the model to the data

# %%
from statsmodels.tsa.api import Holt

model_double = Holt(data)
model_double_holt = model_double.fit()
# Out:
# C:\Users\abo_O\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
from statsmodels.tsa.api import Holt

model_double = Holt(data)
model_double_fit = model_double.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# ## Making predictions

# %%
forecast_double = model_double_holt.forecast(6)
print(forecast_double)
# Out:
# 1961-01-01    436.196220
# 1961-02-01    440.578651
# 1961-03-01    444.961083
# 1961-04-01    449.343515
# 1961-05-01    453.725946
# 1961-06-01    458.108378
# Freq: MS, dtype: float64

# %%
forecast_double = model_double_fit.forecast(6)
print(forecast_double)
# Out:
# 1961-01-01    436.196220
# 1961-02-01    440.578651
# 1961-03-01    444.961083
# 1961-04-01    449.343515
# 1961-05-01    453.725946
# 1961-06-01    458.108378
# Freq: MS, dtype: float64

# %% [markdown]
# ## Visualize Double Exponential Smoothing
# ### Let’s set the forecast to 40, and check the trend for next 40 months, same as earlier.

# %%
forecast_double = model_double_holt.forecast(40)

# %%
forecast_double = model_double_fit.forecast(40)

# %%
plt.plot(data, label='Original Data')
plt.plot(model_double_holt.fittedvalues, label='Fitted Values')
plt.plot(forecast_double, label='Forecast')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.title('Double Exponential Smoothing')
plt.legend()
plt.show()

# %% [markdown]
# #**Holt-Winter’s Seasonal Smoothing**
#
# ### Holt-Winter’s Seasonal Smoothing, extends double exponential smoothing to capture seasonality in the data. It involves forecasting the level, trend, and seasonality components of the time series.
#
# ### Now, let’s write the code to perform triple exponential smoothing (Holt-Winters method) using the ExponentialSmoothing function from the statsmodels library:

# %%
from statsmodels.tsa.api import ExponentialSmoothing

model_triple = ExponentialSmoothing(data, seasonal_periods=12, trend='add', seasonal='add')

model_triple_fit = model_triple.fit()
# Out:
# C:\Users\abo_O\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
from statsmodels.tsa.api import ExponentialSmoothing

# Create an instance of ExponentialSmoothing class
model_triple = ExponentialSmoothing(
    data, seasonal_periods=12, trend='add', seasonal='add')

# Fit the model to the data
model_triple_fit = model_triple.fit()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# ## Making predictions

# %%
forecast_triple = model_triple_fit.forecast(6)
print(forecast_triple)
# Out:
# 1961-01-01    451.577073
# 1961-02-01    427.257748
# 1961-03-01    464.699360
# 1961-04-01    500.103185
# 1961-05-01    508.660794
# 1961-06-01    567.713873
# Freq: MS, dtype: float64

# %%
forecast_triple = model_triple_fit.forecast(6)
print(forecast_triple)
# Out:
# 1961-01-01    451.577073
# 1961-02-01    427.257748
# 1961-03-01    464.699360
# 1961-04-01    500.103185
# 1961-05-01    508.660794
# 1961-06-01    567.713873
# Freq: MS, dtype: float64

# %% [markdown]
# ## Visualize Triple Exponential Smoothing
# ### Let’s set the forecast to 40, and check the trend for next 40 months, same as earlier.

# %%
forecast_triple = model_triple_fit.forecast(60)

# %%
forecast_triple = model_triple_fit.forecast(40)

# %%
plt.plot(data, label='Original Data')
plt.plot(model_triple_fit.fittedvalues, label='Fitted Values')
plt.plot(forecast_triple, label='Forecast')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.title('Triple Exponential Smoothing')
plt.legend()
plt.show()

# %% [markdown]
# ##**Well done :)**
